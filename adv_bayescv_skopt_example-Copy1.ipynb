# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

from sklearn.datasets import load_iris, load_digits
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

import pandas as pd

X, y = load_digits(10, True)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=0)

# used to try different model classes
pipe = Pipeline([
    ('model', SVC())
])

# single categorical value of 'model' parameter is used  to set the model class
lin_search = {
    'model': Categorical([LinearSVC()]),
    'model__C': Real(1e-6, 1e+6, prior='log-uniform'),
}

dtc_search = {
    'model': Categorical([DecisionTreeClassifier()]),
    'model__max_depth': Integer(1,32),
    'model__min_samples_split': Real(1e-3, 1.0, prior='log-uniform'),
}

svc_search = {
    'model': Categorical([SVC()]),
    'model__C': Real(1e-6, 1e+6, prior='log-uniform'),
    'model__gamma': Real(1e-6, 1e+1, prior='log-uniform'),
    'model__degree': Integer(1,8),
    'model__kernel': Categorical(['linear', 'poly', 'rbf']),
}

# %%
opt = BayesSearchCV(
    pipe,
    [(lin_search, 16), (dtc_search, 24), (svc_search, 32)], # (parameter space, # of evaluations)
)

opt.fit(X_train, y_train)
# Out:
# /home/savvas/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "

# %%
opt.best_estimator_
# Out:
# Pipeline(steps=[('model', SVC(C=685.79254083046715, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=1, gamma=0.00067292562584484828,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False))])

# %%
type(opt.cv_results_)
# Out:
# collections.defaultdict

# %%
opt.cv_results_.keys()
# Out:
# dict_keys(['split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score', 'split0_train_score', 'split1_train_score', 'split2_train_score', 'mean_train_score', 'std_train_score', 'mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_model', 'param_model__C', 'params', 'param_model__max_depth', 'param_model__min_samples_split', 'param_model__degree', 'param_model__gamma', 'param_model__kernel', 0])

# %%
len(opt.cv_results_.keys())
# Out:
# 24

# %%
len(opt.cv_results_.items())
# Out:
# 24

# %%
cv_results = pd.DataFrame(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9c08488910b3> in <module>()
# ----> 1 cv_results = pd.DataFrame(opt.cv_results_)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# -> 5496         index = extract_index(arrays)
#    5497     else:
#    5498         index = _ensure_index(index)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5542             lengths = list(set(raw_lengths))
#    5543             if len(lengths) > 1:
# -> 5544                 raise ValueError('arrays must all be same length')
#    5545
#    5546             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
cv_results = pd.DataFrame.from_dict(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a3440fe05c43> in <module>()
# ----> 1 cv_results2 = pd.DataFrame.from_dict(opt.cv_results_)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype)
#     849             raise ValueError('only recognize index or columns for orient')
#     850
# --> 851         return cls(data, index=index, columns=columns, dtype=dtype)
#     852
#     853     def to_dict(self, orient='dict'):
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# -> 5496         index = extract_index(arrays)
#    5497     else:
#    5498         index = _ensure_index(index)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5542             lengths = list(set(raw_lengths))
#    5543             if len(lengths) > 1:
# -> 5544                 raise ValueError('arrays must all be same length')
#    5545
#    5546             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
for k, v in opt.cv_results_.items():
    print(k, len(v))
# Out:
# split0_test_score 72
# split1_test_score 72
# split2_test_score 72
# mean_test_score 72
# std_test_score 72
# rank_test_score 72
# split0_train_score 72
# split1_train_score 72
# split2_train_score 72
# mean_train_score 72
# std_train_score 72
# mean_fit_time 72
# std_fit_time 72
# mean_score_time 72
# std_score_time 72
# param_model 72
# param_model__C 48
# params 72
# param_model__max_depth 24
# param_model__min_samples_split 24
# param_model__degree 32
# param_model__gamma 32
# param_model__kernel 32
# 0 0

# %%
cv_results = pd.DataFrame(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9c08488910b3> in <module>()
# ----> 1 cv_results = pd.DataFrame(opt.cv_results_)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# -> 5496         index = extract_index(arrays)
#    5497     else:
#    5498         index = _ensure_index(index)
#
# ~/miniconda3/envs/wvH2/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5542             lengths = list(set(raw_lengths))
#    5543             if len(lengths) > 1:
# -> 5544                 raise ValueError('arrays must all be same length')
#    5545
#    5546             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### Hacky solutions from [here](https://stackoverflow.com/questions/19736080/creating-dataframe-from-a-dictionary-where-entries-have-different-lengths)

# %%
cv_results = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in opt.cv_results_.items()]))

# %%
cv_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 23 columns):
# mean_fit_time                     72 non-null float64
# mean_score_time                   72 non-null float64
# mean_test_score                   72 non-null float64
# mean_train_score                  72 non-null float64
# param_model                       72 non-null object
# param_model__C                    48 non-null float64
# param_model__degree               32 non-null float64
# param_model__gamma                32 non-null float64
# param_model__kernel               32 non-null object
# param_model__max_depth            24 non-null float64
# param_model__min_samples_split    24 non-null float64
# params                            72 non-null object
# rank_test_score                   72 non-null int64
# split0_test_score                 72 non-null float64
# split0_train_score                72 non-null float64
# split1_test_score                 72 non-null float64
# split1_train_score                72 non-null float64
# split2_test_score                 72 non-null float64
# split2_train_score                72 non-null float64
# std_fit_time                      72 non-null float64
# std_score_time                    72 non-null float64
# std_test_score                    72 non-null float64
# std_train_score                   72 non-null float64
# dtypes: float64(19), int64(1), object(3)
# memory usage: 13.0+ KB

# %%
cv_results2 = pd.DataFrame.from_dict(opt.cv_results_, orient='index').transpose()

# %%
cv_results2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 23 columns):
# split0_test_score                 72 non-null object
# split1_test_score                 72 non-null object
# split2_test_score                 72 non-null object
# mean_test_score                   72 non-null object
# std_test_score                    72 non-null object
# rank_test_score                   72 non-null object
# split0_train_score                72 non-null object
# split1_train_score                72 non-null object
# split2_train_score                72 non-null object
# mean_train_score                  72 non-null object
# std_train_score                   72 non-null object
# mean_fit_time                     72 non-null object
# std_fit_time                      72 non-null object
# mean_score_time                   72 non-null object
# std_score_time                    72 non-null object
# param_model                       72 non-null object
# param_model__C                    48 non-null object
# params                            72 non-null object
# param_model__max_depth            24 non-null object
# param_model__min_samples_split    24 non-null object
# param_model__degree               32 non-null object
# param_model__gamma                32 non-null object
# param_model__kernel               32 non-null object
# dtypes: object(23)
# memory usage: 13.0+ KB

# %%
pd.options.display.max_columns = None

# %%
cv_results.sort_values('rank_test_score')
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.014464         0.006983         0.953229          0.967710
# 51       0.025666         0.010797         0.985152          1.000000
# 50       0.023060         0.012570         0.983667          1.000000
# 49       0.102624         0.028297         0.521901          0.532648
# 48       0.061855         0.025199         0.919079          0.928363
# 47       0.017992         0.009748         0.976986          1.000000
# 46       0.025827         0.015129         0.978471          1.000000
# 52       0.107106         0.029879         0.106162          0.106161
# 45       0.056607         0.024344         0.925019          0.936893
# 43       0.023503         0.010355         0.985152          1.000000
# 42       0.018071         0.009738         0.976986          1.000000
# 41       0.163058         0.041139         0.106162          0.106161
# 40       0.170217         0.045180         0.106162          0.106161
# 39       0.008778         0.000283         0.847068          1.000000
# 38       0.008774         0.000288         0.834447          1.000000
SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 55  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 69  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 68  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 67  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 66  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 65  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 64  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 54  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 63  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 61  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 60  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 59  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# ..                                                ...             ...
# 9   LinearSVC(C=0.0014842761922023431, class_weigh...       13.286262
# 15  LinearSVC(C=0.0014842761922023431, class_weigh...        0.001362
# 8   LinearSVC(C=0.0014842761922023431, class_weigh...       79.009738
# 6   LinearSVC(C=0.0014842761922023431, class_weigh...        0.010132
# 5   LinearSVC(C=0.0014842761922023431, class_weigh...        5.381756
# 4   LinearSVC(C=0.0014842761922023431, class_weigh...        2.479329
# 3   LinearSVC(C=0.0014842761922023431, class_weigh...      132.983036
# 2   LinearSVC(C=0.0014842761922023431, class_weigh...      913.174291
# 1   LinearSVC(C=0.0014842761922023431, class_weigh...        5.519725
# 7   LinearSVC(C=0.0014842761922023431, class_weigh...        0.110095
# 16  DecisionTreeClassifier(class_weight=None, crit...        0.000002
# 17  DecisionTreeClassifier(class_weight=None, crit...        0.000033
# 18  DecisionTreeClassifier(class_weight=None, crit...     1093.350679
# 33  DecisionTreeClassifier(class_weight=None, crit...        0.000007
# 32  DecisionTreeClassifier(class_weight=None, crit...   163035.503010
# 31  DecisionTreeClassifier(class_weight=None, crit...        0.000002
# 30  DecisionTreeClassifier(class_weight=None, crit...        0.001473
# 29  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 28  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 27  DecisionTreeClassifier(class_weight=None, crit...        0.001206
# 26  DecisionTreeClassifier(class_weight=None, crit...        0.000004
# 25  DecisionTreeClassifier(class_weight=None, crit...        0.002821
# 24  DecisionTreeClassifier(class_weight=None, crit...        0.000038
# 23  DecisionTreeClassifier(class_weight=None, crit...        0.057718
# 22  DecisionTreeClassifier(class_weight=None, crit...   364753.147467
# 21  DecisionTreeClassifier(class_weight=None, crit...        0.000046
# 20  DecisionTreeClassifier(class_weight=None, crit...      283.049858
# 19  DecisionTreeClassifier(class_weight=None, crit...        0.001385
# 70  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 71  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
#
#     param_model__degree  param_model__gamma param_model__kernel  \
# 0                   3.0            0.059852                 rbf
# 51                  NaN                 NaN                 NaN
# 50                  NaN                 NaN                 NaN
# 49                  NaN                 NaN                 NaN
# 48                  NaN                 NaN                 NaN
# 47                  NaN                 NaN                 NaN
# 46                  NaN                 NaN                 NaN
# 52                  NaN                 NaN                 NaN
# 45                  NaN                 NaN                 NaN
# 43                  NaN                 NaN                 NaN
# 42                  NaN                 NaN                 NaN
# 41                  NaN                 NaN                 NaN
# 40                  NaN                 NaN                 NaN
# 39                  NaN                 NaN                 NaN
# 38                  NaN                 NaN                 NaN
# 44                  NaN                 NaN                 NaN
# 37                  NaN                 NaN                 NaN
# 53                  NaN                 NaN                 NaN
# 55                  NaN                 NaN                 NaN
# 69                  NaN                 NaN                 NaN
# 68                  NaN                 NaN                 NaN
# 67                  NaN                 NaN                 NaN
# 66                  NaN                 NaN                 NaN
# 65                  NaN                 NaN                 NaN
# 64                  NaN                 NaN                 NaN
# 54                  NaN                 NaN                 NaN
# 63                  NaN                 NaN                 NaN
# 61                  NaN                 NaN                 NaN
# 60                  NaN                 NaN                 NaN
# 59                  NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 9                   1.0            0.003580                poly
# 15                  2.0            0.000002                 rbf
# 8                   7.0            1.845609              linear
# 6                   1.0            0.000011                 rbf
# 5                   6.0            0.000202              linear
# 4                   2.0            0.002405                 rbf
# 3                   4.0            0.549278                poly
# 2                   2.0            0.000021              linear
# 1                   8.0            0.000826                 rbf
# 7                   5.0            0.068241              linear
# 16                  3.0            0.000022                 rbf
# 17                  1.0            0.000001                poly
# 18                  8.0            0.026215              linear
# 33                  NaN                 NaN                 NaN
# 32                  NaN                 NaN                 NaN
# 31                  8.0            0.003096                poly
# 30                  8.0            0.000001              linear
# 29                  8.0            0.000020              linear
# 28                  1.0            0.000608                 rbf
# 27                  8.0            0.000001              linear
# 26                  1.0            4.357721              linear
# 25                  8.0            0.000435                 rbf
# 24                  1.0            0.316692              linear
# 23                  1.0           10.000000              linear
# 22                  1.0            0.000377              linear
# 21                  5.0            0.001509              linear
# 20                  1.0            0.000673                 rbf
# 19                  1.0            1.629449                poly
# 70                  NaN                 NaN                 NaN
# 71                  NaN                 NaN                 NaN
#
#     param_model__max_depth  param_model__min_samples_split  \
# 0                     15.0                        0.030931
# 51                     NaN                             NaN
# 50                     NaN                             NaN
# 49                     NaN                             NaN
# 48                     NaN                             NaN
# 47                     NaN                             NaN
# 46                     NaN                             NaN
# 52                     NaN                             NaN
# 45                     NaN                             NaN
# 43                     NaN                             NaN
# 42                     NaN                             NaN
# 41                     NaN                             NaN
# 40                     NaN                             NaN
# 39                     NaN                             NaN
# 38                     NaN                             NaN
# 44                     NaN                             NaN
# 37                     NaN                             NaN
# 53                     NaN                             NaN
# 55                     NaN                             NaN
# 69                     NaN                             NaN
# 68                     NaN                             NaN
# 67                     NaN                             NaN
# 66                     NaN                             NaN
# 65                     NaN                             NaN
# 64                     NaN                             NaN
# 54                     NaN                             NaN
# 63                     NaN                             NaN
# 61                     NaN                             NaN
# 60                     NaN                             NaN
# 59                     NaN                             NaN
# ..                     ...                             ...
# 9                     11.0                        0.151634
# 15                    29.0                        0.001000
# 8                     10.0                        0.313663
# 6                     18.0                        0.197814
# 5                     28.0                        0.015547
# 4                     24.0                        0.076772
# 3                     32.0                        0.041842
# 2                     13.0                        0.009371
# 1                      1.0                        0.016146
# 7                     26.0                        0.091981
# 16                    12.0                        0.001000
# 17                    12.0                        0.001000
# 18                    32.0                        0.003720
# 33                     NaN                             NaN
# 32                     NaN                             NaN
# 31                     NaN                             NaN
# 30                     NaN                             NaN
# 29                     NaN                             NaN
# 28                     NaN                             NaN
# 27                     NaN                             NaN
# 26                     NaN                             NaN
# 25                     NaN                             NaN
# 24                     NaN                             NaN
# 23                    22.0                        0.001000
# 22                    12.0                        0.001000
# 21                    12.0                        0.001000
# 20                    30.0                        0.001000
# 19                    12.0                        0.001000
# 70                     NaN                             NaN
# 71                     NaN                             NaN
#
#                                                params  rank_test_score  \
# 0   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 51  {'model': SVC(C=685.79254083046715, cache_size...                1
# 50  {'model': SVC(C=685.79254083046715, cache_size...                1
# 49  {'model': SVC(C=685.79254083046715, cache_size...                1
# 48  {'model': SVC(C=685.79254083046715, cache_size...                1
# 47  {'model': SVC(C=685.79254083046715, cache_size...                1
# 46  {'model': SVC(C=685.79254083046715, cache_size...                1
# 52  {'model': SVC(C=685.79254083046715, cache_size...                1
# 45  {'model': SVC(C=685.79254083046715, cache_size...                1
# 43  {'model': SVC(C=685.79254083046715, cache_size...                1
# 42  {'model': SVC(C=685.79254083046715, cache_size...                1
# 41  {'model': SVC(C=685.79254083046715, cache_size...                1
# 40  {'model': SVC(C=685.79254083046715, cache_size...                1
# 39  {'model': DecisionTreeClassifier(class_weight=...                1
# 38  {'model': DecisionTreeClassifier(class_weight=...                1
# 44  {'model': SVC(C=685.79254083046715, cache_size...                1
# 37  {'model': DecisionTreeClassifier(class_weight=...                1
# 53  {'model': SVC(C=685.79254083046715, cache_size...                1
# 55  {'model': SVC(C=685.79254083046715, cache_size...                1
# 69  {'model': SVC(C=685.79254083046715, cache_size...                1
# 68  {'model': SVC(C=685.79254083046715, cache_size...                1
# 67  {'model': SVC(C=685.79254083046715, cache_size...                1
# 66  {'model': SVC(C=685.79254083046715, cache_size...                1
# 65  {'model': SVC(C=685.79254083046715, cache_size...                1
# 64  {'model': SVC(C=685.79254083046715, cache_size...                1
# 54  {'model': SVC(C=685.79254083046715, cache_size...                1
# 63  {'model': SVC(C=685.79254083046715, cache_size...                1
# 61  {'model': SVC(C=685.79254083046715, cache_size...                1
# 60  {'model': SVC(C=685.79254083046715, cache_size...                1
# 59  {'model': SVC(C=685.79254083046715, cache_size...                1
# ..                                                ...              ...
# 9   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 15  {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 8   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 6   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 5   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 4   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 3   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 2   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 1   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 7   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 16  {'model': DecisionTreeClassifier(class_weight=...                1
# 17  {'model': DecisionTreeClassifier(class_weight=...                1
# 18  {'model': DecisionTreeClassifier(class_weight=...                1
# 33  {'model': DecisionTreeClassifier(class_weight=...                1
# 32  {'model': DecisionTreeClassifier(class_weight=...                1
# 31  {'model': DecisionTreeClassifier(class_weight=...                1
# 30  {'model': DecisionTreeClassifier(class_weight=...                1
# 29  {'model': DecisionTreeClassifier(class_weight=...                1
# 28  {'model': DecisionTreeClassifier(class_weight=...                1
# 27  {'model': DecisionTreeClassifier(class_weight=...                1
# 26  {'model': DecisionTreeClassifier(class_weight=...                1
# 25  {'model': DecisionTreeClassifier(class_weight=...                1
# 24  {'model': DecisionTreeClassifier(class_weight=...                1
# 23  {'model': DecisionTreeClassifier(class_weight=...                1
# 22  {'model': DecisionTreeClassifier(class_weight=...                1
# 21  {'model': DecisionTreeClassifier(class_weight=...                1
# 20  {'model': DecisionTreeClassifier(class_weight=...                1
# 19  {'model': DecisionTreeClassifier(class_weight=...                1
# 70  {'model': SVC(C=685.79254083046715, cache_size...                1
# 71  {'model': SVC(C=685.79254083046715, cache_size...                1
#
#     split0_test_score  split0_train_score  split1_test_score  \
# 0            0.942478            0.970950           0.966592
# 51           0.984513            1.000000           0.984410
# 50           0.982301            1.000000           0.984410
# 49           0.517699            0.521788           0.514477
# 48           0.900442            0.931844           0.939866
# 47           0.971239            1.000000           0.975501
# 46           0.971239            1.000000           0.977728
# 52           0.106195            0.106145           0.106904
# 45           0.902655            0.936313           0.946548
# 43           0.984513            1.000000           0.984410
# 42           0.971239            1.000000           0.975501
# 41           0.106195            0.106145           0.106904
# 40           0.106195            0.106145           0.106904
# 39           0.847345            1.000000           0.857461
# 38           0.831858            1.000000           0.846325
# 44           0.986726            1.000000           0.993318
# 37           0.853982            1.000000           0.846325
# 53           0.106195            1.000000           0.106904
# 55           0.106195            0.106145           0.106904
# 69           0.971239            1.000000           0.975501
# 68           0.988938            1.000000           0.991091
# 67           0.971239            1.000000           0.975501
# 66           0.971239            1.000000           0.975501
# 65           0.988938            1.000000           0.988864
# 64           0.971239            1.000000           0.975501
# 54           0.971239            1.000000           0.975501
# 63           0.971239            1.000000           0.975501
# 61           0.971239            1.000000           0.975501
# 60           0.991150            1.000000           0.991091
# 59           0.977876            0.991061           0.973274
# ..                ...                 ...                ...
# 9            0.944690            0.995531           0.924276
# 15           0.955752            0.991061           0.964365
# 8            0.949115            0.997765           0.942094
# 6            0.951327            0.995531           0.957684
# 5            0.940265            0.998883           0.942094
# 4            0.942478            0.997765           0.944321
# 3            0.944690            1.000000           0.942094
# 2            0.944690            0.997765           0.939866
# 1            0.944690            0.996648           0.935412
# 7            0.949115            0.995531           0.942094
# 16           0.818584            0.873743           0.781737
# 17           0.207965            0.203352           0.204900
# 18           0.836283            0.937430           0.828508
# 33           0.840708            1.000000           0.839644
# 32           0.847345            1.000000           0.850780
# 31           0.840708            1.000000           0.841871
# 30           0.834071            1.000000           0.844098
# 29           0.851770            1.000000           0.848552
# 28           0.849558            1.000000           0.844098
# 27           0.847345            1.000000           0.839644
# 26           0.831858            0.968715           0.841871
# 25           0.685841            0.699441           0.634744
SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 69  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 64  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 63  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 42  SVC(C=685.79254083046715, cache_size=200, clas...   119827.207847
# 61  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 47  SVC(C=685.79254083046715, cache_size=200, clas...     1223.964396
# 70  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 58  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 62  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 54  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 71  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 12  LinearSVC(C=0.0014842761922023431, class_weigh...        0.001484
# 13  LinearSVC(C=0.0014842761922023431, class_weigh...        0.001467
# 15  LinearSVC(C=0.0014842761922023431, class_weigh...        0.001362
# 6   LinearSVC(C=0.0014842761922023431, class_weigh...        0.010132
# 0   LinearSVC(C=0.0014842761922023431, class_weigh...        0.000167
# 7   LinearSVC(C=0.0014842761922023431, class_weigh...        0.110095
# 4   LinearSVC(C=0.0014842761922023431, class_weigh...        2.479329
# ..                                                ...             ...
# 32  DecisionTreeClassifier(class_weight=None, crit...   163035.503010
# 28  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 36  DecisionTreeClassifier(class_weight=None, crit...      685.792541
# 29  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 35  DecisionTreeClassifier(class_weight=None, crit...        0.000844
# 37  DecisionTreeClassifier(class_weight=None, crit...      188.292479
# 30  DecisionTreeClassifier(class_weight=None, crit...        0.001473
# 27  DecisionTreeClassifier(class_weight=None, crit...        0.001206
# 31  DecisionTreeClassifier(class_weight=None, crit...        0.000002
# 26  DecisionTreeClassifier(class_weight=None, crit...        0.000004
# 34  DecisionTreeClassifier(class_weight=None, crit...    27284.113723
# 38  DecisionTreeClassifier(class_weight=None, crit...    76774.109802
# 33  DecisionTreeClassifier(class_weight=None, crit...        0.000007
# 18  DecisionTreeClassifier(class_weight=None, crit...     1093.350679
# 21  DecisionTreeClassifier(class_weight=None, crit...        0.000046
# 16  DecisionTreeClassifier(class_weight=None, crit...        0.000002
# 19  DecisionTreeClassifier(class_weight=None, crit...        0.001385
# 20  DecisionTreeClassifier(class_weight=None, crit...      283.049858
# 23  DecisionTreeClassifier(class_weight=None, crit...        0.057718
# 25  DecisionTreeClassifier(class_weight=None, crit...        0.002821
# 22  DecisionTreeClassifier(class_weight=None, crit...   364753.147467
# 49  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 24  DecisionTreeClassifier(class_weight=None, crit...        0.000038
# 17  DecisionTreeClassifier(class_weight=None, crit...        0.000033
# 41  SVC(C=685.79254083046715, cache_size=200, clas...      925.054174
# 40  SVC(C=685.79254083046715, cache_size=200, clas...       34.457336
# 57  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 55  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 53  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
# 52  SVC(C=685.79254083046715, cache_size=200, clas...             NaN
#
#     param_model__degree  param_model__gamma param_model__kernel  \
# 60                  NaN                 NaN                 NaN
# 68                  NaN                 NaN                 NaN
# 65                  NaN                 NaN                 NaN
# 44                  NaN                 NaN                 NaN
# 43                  NaN                 NaN                 NaN
# 51                  NaN                 NaN                 NaN
# 50                  NaN                 NaN                 NaN
# 56                  NaN                 NaN                 NaN
# 59                  NaN                 NaN                 NaN
# 46                  NaN                 NaN                 NaN
# 67                  NaN                 NaN                 NaN
# 66                  NaN                 NaN                 NaN
# 69                  NaN                 NaN                 NaN
# 34                     NaN                             NaN
# 38                     NaN                             NaN
# 33                     NaN                             NaN
# 18                    32.0                        0.003720
# 21                    12.0                        0.001000
# 16                    12.0                        0.001000
# 19                    12.0                        0.001000
# 20                    30.0                        0.001000
# 23                    22.0                        0.001000
# 25                     NaN                             NaN
# 22                    12.0                        0.001000
# 49                     NaN                             NaN
# 24                     NaN                             NaN
# 17                    12.0                        0.001000
# 41                     NaN                             NaN
# 40                     NaN                             NaN
# 57                     NaN                             NaN
# 55                     NaN                             NaN
# 53                     NaN                             NaN
# 52                     NaN                             NaN
#
#                                                params  rank_test_score  \
# 60  {'model': SVC(C=685.79254083046715, cache_size...                1
# 68  {'model': SVC(C=685.79254083046715, cache_size...                1
# 65  {'model': SVC(C=685.79254083046715, cache_size...                1
# 44  {'model': SVC(C=685.79254083046715, cache_size...                1
# 43  {'model': SVC(C=685.79254083046715, cache_size...                1
# 51  {'model': SVC(C=685.79254083046715, cache_size...                1
# 50  {'model': SVC(C=685.79254083046715, cache_size...                1
# 56  {'model': SVC(C=685.79254083046715, cache_size...                1
# 59  {'model': SVC(C=685.79254083046715, cache_size...                1
# 46  {'model': SVC(C=685.79254083046715, cache_size...                1
# 67  {'model': SVC(C=685.79254083046715, cache_size...                1
# 66  {'model': SVC(C=685.79254083046715, cache_size...                1
# 69  {'model': SVC(C=685.79254083046715, cache_size...                1
# 64  {'model': SVC(C=685.79254083046715, cache_size...                1
# 63  {'model': SVC(C=685.79254083046715, cache_size...                1
# 42  {'model': SVC(C=685.79254083046715, cache_size...                1
# 61  {'model': SVC(C=685.79254083046715, cache_size...                1
# 47  {'model': SVC(C=685.79254083046715, cache_size...                1
# 70  {'model': SVC(C=685.79254083046715, cache_size...                1
# 58  {'model': SVC(C=685.79254083046715, cache_size...                1
# 62  {'model': SVC(C=685.79254083046715, cache_size...                1
# 54  {'model': SVC(C=685.79254083046715, cache_size...                1
# 71  {'model': SVC(C=685.79254083046715, cache_size...                1
# 12  {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 13  {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 15  {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 6   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 0   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 7   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# 4   {'model': LinearSVC(C=0.0014842761922023431, c...                1
# ..                                                ...              ...
# 32  {'model': DecisionTreeClassifier(class_weight=...                1
# 28  {'model': DecisionTreeClassifier(class_weight=...                1
# 36  {'model': DecisionTreeClassifier(class_weight=...                1
# 29  {'model': DecisionTreeClassifier(class_weight=...                1
# 35  {'model': DecisionTreeClassifier(class_weight=...                1
# 37  {'model': DecisionTreeClassifier(class_weight=...                1
# 30  {'model': DecisionTreeClassifier(class_weight=...                1
# 27  {'model': DecisionTreeClassifier(class_weight=...                1
# 31  {'model': DecisionTreeClassifier(class_weight=...                1
# 26  {'model': DecisionTreeClassifier(class_weight=...                1
# 34  {'model': DecisionTreeClassifier(class_weight=...                1
# 38  {'model': DecisionTreeClassifier(class_weight=...                1
# 33  {'model': DecisionTreeClassifier(class_weight=...                1
# 18  {'model': DecisionTreeClassifier(class_weight=...                1
# 21  {'model': DecisionTreeClassifier(class_weight=...                1
# 16  {'model': DecisionTreeClassifier(class_weight=...                1
# 19  {'model': DecisionTreeClassifier(class_weight=...                1
# 20  {'model': DecisionTreeClassifier(class_weight=...                1
# 23  {'model': DecisionTreeClassifier(class_weight=...                1
# 25  {'model': DecisionTreeClassifier(class_weight=...                1
# 22  {'model': DecisionTreeClassifier(class_weight=...                1
# 49  {'model': SVC(C=685.79254083046715, cache_size...                1
# 24  {'model': DecisionTreeClassifier(class_weight=...                1
# 17  {'model': DecisionTreeClassifier(class_weight=...                1
# 41  {'model': SVC(C=685.79254083046715, cache_size...                1
# 40  {'model': SVC(C=685.79254083046715, cache_size...                1
# 57  {'model': SVC(C=685.79254083046715, cache_size...                1
# 55  {'model': SVC(C=685.79254083046715, cache_size...                1
# 53  {'model': SVC(C=685.79254083046715, cache_size...                1
# 52  {'model': SVC(C=685.79254083046715, cache_size...                1
#
#     split0_test_score  split0_train_score  split1_test_score  \
# 60           0.991150            1.000000           0.991091
# 68           0.988938            1.000000           0.991091
# 65           0.988938            1.000000           0.988864
# 44           0.986726            1.000000           0.993318
# 43           0.984513            1.000000           0.984410
# 51           0.984513            1.000000           0.984410
# 50           0.982301            1.000000           0.984410
# 56           0.975664            1.000000           0.977728
# 59           0.977876            0.991061           0.973274
# 46           0.971239            1.000000           0.977728
# 67           0.971239            1.000000           0.975501
# 66           0.971239            1.000000           0.975501
# 69           0.971239            1.000000           0.975501
# 64           0.971239            1.000000           0.975501
# 63           0.971239            1.000000           0.975501
# 42           0.971239            1.000000           0.975501
# 61           0.971239            1.000000           0.975501
# 47           0.971239            1.000000           0.975501
# 70           0.971239            1.000000           0.975501
# 58           0.971239            1.000000           0.975501
# 62           0.971239            1.000000           0.975501
# 54           0.971239            1.000000           0.975501
# 71           0.964602            1.000000           0.973274
# 12           0.957965            0.991061           0.964365
# 13           0.957965            0.991061           0.964365
# 15           0.955752            0.991061           0.964365
# 6            0.951327            0.995531           0.957684
# 0            0.942478            0.970950           0.966592
# 7            0.949115            0.995531           0.942094
# 4            0.942478            0.997765           0.944321
# ..                ...                 ...                ...
# 32           0.847345            1.000000           0.850780
# 28           0.849558            1.000000           0.844098
# 36           0.838496            1.000000           0.861915
# 29           0.851770            1.000000           0.848552
# 35           0.840708            1.000000           0.853007
# 37           0.853982            1.000000           0.846325
# 30           0.834071            1.000000           0.844098
# 27           0.847345            1.000000           0.839644
# 31           0.840708            1.000000           0.841871
# 26           0.831858            0.968715           0.841871
# 34           0.829646            0.968715           0.839644
# 38           0.831858            1.000000           0.846325
# 33           0.840708            1.000000           0.839644
# 18           0.836283            0.937430           0.828508
