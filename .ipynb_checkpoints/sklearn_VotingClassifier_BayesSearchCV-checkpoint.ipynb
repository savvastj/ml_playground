# %%
from sklearn import datasets

iris = datasets.load_iris()
X, y = iris.data, iris.target

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from sklearn.ensemble import VotingClassifier
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

# %%
clf1 = LogisticRegression(random_state=1)
clf2 = RandomForestClassifier(random_state=1)
clf3 = KNeighborsClassifier()
# eclf = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('knn', clf3)])

# eclf.get_params().keys()

# %%
weights = [[1,1,1], [2,1,1], [1,2,1], [1,1,2], [2,2,1], [2,1,2], [1,2,2]]

# %%
# params = {'lr__C': Real(1e-6, 1e6, prior='log-uniform'),
#           'rf__max_features': Integer(1,4),
#           'knn__n_neighbors': Integer(1,20),
#           'weights': Categorical(weights), 
#           'voting': ['soft', 'hard']}

# %% [markdown]
# Hack to construct multiple models with different weights as I can't pass in a list of lists when searching through parameter spaces using BayesSearchCV

# %%
from sklearn.pipeline import Pipeline

clfs = [('lr', clf1), ('rf', clf2), ('knn', clf3)]
pipe = Pipeline([('model', VotingClassifier(estimators=[('lr', clf1), 
                                                        ('rf', clf2), 
                                                        ('knn', clf3)]))])

pipe.get_params().keys()
# Out:
# dict_keys(['steps', 'model', 'model__estimators', 'model__n_jobs', 'model__voting', 'model__weights', 'model__lr', 'model__rf', 'model__knn', 'model__lr__C', 'model__lr__class_weight', 'model__lr__dual', 'model__lr__fit_intercept', 'model__lr__intercept_scaling', 'model__lr__max_iter', 'model__lr__multi_class', 'model__lr__n_jobs', 'model__lr__penalty', 'model__lr__random_state', 'model__lr__solver', 'model__lr__tol', 'model__lr__verbose', 'model__lr__warm_start', 'model__rf__bootstrap', 'model__rf__class_weight', 'model__rf__criterion', 'model__rf__max_depth', 'model__rf__max_features', 'model__rf__max_leaf_nodes', 'model__rf__min_impurity_split', 'model__rf__min_samples_leaf', 'model__rf__min_samples_split', 'model__rf__min_weight_fraction_leaf', 'model__rf__n_estimators', 'model__rf__n_jobs', 'model__rf__oob_score', 'model__rf__random_state', 'model__rf__verbose', 'model__rf__warm_start', 'model__knn__algorithm', 'model__knn__leaf_size', 'model__knn__metric', 'model__knn__metric_params', 'model__knn__n_jobs', 'model__knn__n_neighbors', 'model__knn__p', 'model__knn__weights'])

# %%
search_spaces = []

for weight in weights:
    # hacky way to test out weights is by constructing a search space
    # for each one
    params = {'model': Categorical([VotingClassifier(estimators=clfs, 
                                                     weights=weight)]),
              'model__lr__C': Real(1e-6, 1e6, prior='log-uniform'),
              'model__rf__max_features': Integer(1,4),
              'model__knn__n_neighbors': Integer(1,20),
              'model__voting': ['soft', 'hard']}
    search_spaces.append((params, 20))

# %%
## was testing out individual search spaces befor using above for loop
## to construct a bunch of them
# first_srch = {'model': Categorical([VotingClassifier(estimators=clfs, 
#                                                      weights=weights[0])]),
#               'model__lr__C': Real(1e-6, 1e6, prior='log-uniform'),
#               'model__rf__max_features': Integer(1,4),
#               'model__knn__n_neighbors': Integer(1,20),
#               'model__voting': ['soft', 'hard']}
# scnd_srch =  {'model': Categorical([VotingClassifier(estimators=clfs, 
#                                                      weights=weights[1])]),
#               'model__lr__C': Real(1e-6, 1e6, prior='log-uniform'),
#               'model__rf__max_features': Integer(1,4),
#               'model__knn__n_neighbors': Integer(1,20),
#               'model__voting': ['soft', 'hard']}

# %%
grid = BayesSearchCV(pipe, search_spaces=search_spaces, cv=5, n_jobs=-1)
grid.fit(iris.data, iris.target)
# Out:
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /home/savvas-mint/python_dev_pkgs/scikit-optimize/skopt/optimizer/optimizer.py:363: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('model', VotingClassifier(estimators=[('lr', LogisticRegression(C=847832.95827448287, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=1,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)), ('...wski',
#            metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#            weights='uniform'))],
#          n_jobs=1, voting='hard', weights=[1, 1, 2]))])

# %%
import pandas as pd

# %%
cv_results = pd.DataFrame(grid.cv_results_)

# %%
pd.options.display.max_columns = None

# %%
cv_results.sort_values('mean_test_score', ascending=False)
# Out:
#      mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 90        0.022590         0.002729         0.980000          0.976667
# 89        0.025580         0.003106         0.980000          0.975000
# 127       0.022266         0.002660         0.980000          0.993333
# 0         0.024278         0.003289         0.973333          0.991667
# 145       0.024957         0.002583         0.973333          0.986667
# 99        0.023620         0.002889         0.973333          0.990000
# 31        0.023099         0.002817         0.973333          0.981667
# 93        0.022461         0.002805         0.973333          0.980000
# 88        0.025773         0.003417         0.973333          0.973333
# 123       0.024813         0.002337         0.973333          0.980000
# 124       0.023348         0.002877         0.973333          0.990000
# 129       0.021593         0.003041         0.973333          0.988333
# 144       0.026189         0.003512         0.973333          0.988333
# 76        0.019552         0.001959         0.973333          0.978333
# 9         0.023756         0.003052         0.973333          0.993333
# 8         0.024241         0.003378         0.973333          0.990000
# 5         0.023063         0.002586         0.973333          0.990000
# 153       0.023221         0.003047         0.973333          0.991667
# 63        0.023924         0.002155         0.966667          1.000000
# 95        0.021705         0.002283         0.966667          1.000000
# 64        0.024867         0.003254         0.966667          0.998333
# 65        0.025058         0.003061         0.966667          0.998333
# 91        0.024016         0.002930         0.966667          1.000000
# 67        0.023822         0.002995         0.966667          1.000000
# 71        0.023445         0.002728         0.966667          0.998333
# 72        0.025698         0.002698         0.966667          0.980000
# 82        0.020885         0.002923         0.966667          0.968333
# 68        0.023210         0.002642         0.966667          0.998333
# 70        0.021887         0.002697         0.966667          1.000000
# 81        0.024448         0.002466         0.966667          0.985000
# ..             ...              ...              ...               ...
# 42        0.022972         0.002803         0.960000          0.990000
# 84        0.023855         0.002963         0.960000          0.968333
# 40        0.025527         0.002947         0.960000          0.983333
# 100       0.023842         0.002414         0.960000          0.990000
# 110       0.021723         0.002617         0.960000          1.000000
# 108       0.023470         0.002768         0.960000          1.000000
# 107       0.024350         0.002931         0.960000          1.000000
# 39        0.018348         0.002327         0.960000          1.000000
# 105       0.023747         0.003073         0.960000          0.986667
# 27        0.020958         0.002621         0.960000          0.976667
# 101       0.024134         0.002451         0.960000          0.993333
# 30        0.021200         0.001971         0.960000          0.988333
# 34        0.022761         0.002753         0.960000          1.000000
# 35        0.023271         0.003077         0.960000          0.990000
# 36        0.023289         0.002902         0.960000          1.000000
# 37        0.021079         0.002759         0.960000          0.990000
# 94        0.023100         0.002147         0.960000          1.000000
# 38        0.019483         0.002477         0.960000          0.990000
# 92        0.024529         0.002256         0.960000          1.000000
# 111       0.022811         0.002781         0.960000          1.000000
# 61        0.022429         0.002643         0.953333          1.000000
# 60        0.020482         0.001905         0.953333          1.000000
# 55        0.023596         0.002838         0.953333          1.000000
# 54        0.019623         0.002672         0.953333          1.000000
# 154       0.022766         0.002776         0.953333          1.000000
# 159       0.023430         0.002825         0.953333          1.000000
# 109       0.020501         0.002515         0.953333          1.000000
# 157       0.025218         0.002920         0.953333          1.000000
# 126       0.022562         0.002389         0.953333          0.981667
# 86        0.021627         0.002393         0.953333          0.981667
#
#                                            param_model  \
# 90   VotingClassifier(estimators=[('lr', LogisticRe...
# 89   VotingClassifier(estimators=[('lr', LogisticRe...
# 127  VotingClassifier(estimators=[('lr', LogisticRe...
# 0    VotingClassifier(estimators=[('lr', LogisticRe...
# 145  VotingClassifier(estimators=[('lr', LogisticRe...
# 99   VotingClassifier(estimators=[('lr', LogisticRe...
# 31   VotingClassifier(estimators=[('lr', LogisticRe...
# 93   VotingClassifier(estimators=[('lr', LogisticRe...
# 88   VotingClassifier(estimators=[('lr', LogisticRe...
# 123  VotingClassifier(estimators=[('lr', LogisticRe...
# 124  VotingClassifier(estimators=[('lr', LogisticRe...
# 129  VotingClassifier(estimators=[('lr', LogisticRe...
# 144  VotingClassifier(estimators=[('lr', LogisticRe...
# 76   VotingClassifier(estimators=[('lr', LogisticRe...
# 9    VotingClassifier(estimators=[('lr', LogisticRe...
# 8    VotingClassifier(estimators=[('lr', LogisticRe...
# 5    VotingClassifier(estimators=[('lr', LogisticRe...
# 153  VotingClassifier(estimators=[('lr', LogisticRe...
# 63   VotingClassifier(estimators=[('lr', LogisticRe...
# 95   VotingClassifier(estimators=[('lr', LogisticRe...
# 64   VotingClassifier(estimators=[('lr', LogisticRe...
# 65   VotingClassifier(estimators=[('lr', LogisticRe...
# 91   VotingClassifier(estimators=[('lr', LogisticRe...
# 67   VotingClassifier(estimators=[('lr', LogisticRe...
# 71   VotingClassifier(estimators=[('lr', LogisticRe...
# 72   VotingClassifier(estimators=[('lr', LogisticRe...
# 82   VotingClassifier(estimators=[('lr', LogisticRe...
# 68   VotingClassifier(estimators=[('lr', LogisticRe...
# 70   VotingClassifier(estimators=[('lr', LogisticRe...
# 81   VotingClassifier(estimators=[('lr', LogisticRe...
# ..                                                 ...
# 42   VotingClassifier(estimators=[('lr', LogisticRe...
# 84   VotingClassifier(estimators=[('lr', LogisticRe...
# 40   VotingClassifier(estimators=[('lr', LogisticRe...
# 100  VotingClassifier(estimators=[('lr', LogisticRe...
# 110  VotingClassifier(estimators=[('lr', LogisticRe...
# 108  VotingClassifier(estimators=[('lr', LogisticRe...
# 107  VotingClassifier(estimators=[('lr', LogisticRe...
# 39   VotingClassifier(estimators=[('lr', LogisticRe...
# 105  VotingClassifier(estimators=[('lr', LogisticRe...
# 27   VotingClassifier(estimators=[('lr', LogisticRe...
# 101  VotingClassifier(estimators=[('lr', LogisticRe...
# 30   VotingClassifier(estimators=[('lr', LogisticRe...
# 34   VotingClassifier(estimators=[('lr', LogisticRe...
# 35   VotingClassifier(estimators=[('lr', LogisticRe...
# 36   VotingClassifier(estimators=[('lr', LogisticRe...
# 37   VotingClassifier(estimators=[('lr', LogisticRe...
# 94   VotingClassifier(estimators=[('lr', LogisticRe...
# 38   VotingClassifier(estimators=[('lr', LogisticRe...
# 92   VotingClassifier(estimators=[('lr', LogisticRe...
# 111  VotingClassifier(estimators=[('lr', LogisticRe...
# 61   VotingClassifier(estimators=[('lr', LogisticRe...
# 60   VotingClassifier(estimators=[('lr', LogisticRe...
# 55   VotingClassifier(estimators=[('lr', LogisticRe...
# 54   VotingClassifier(estimators=[('lr', LogisticRe...
# 154  VotingClassifier(estimators=[('lr', LogisticRe...
# 159  VotingClassifier(estimators=[('lr', LogisticRe...
# 109  VotingClassifier(estimators=[('lr', LogisticRe...
# 157  VotingClassifier(estimators=[('lr', LogisticRe...
# 126  VotingClassifier(estimators=[('lr', LogisticRe...
# 86   VotingClassifier(estimators=[('lr', LogisticRe...
#
#      param_model__knn__n_neighbors  param_model__lr__C  \
# 90                              11      1000000.000000
# 89                              12       847832.958274
# 127                             10            7.617789
# 0                               14            6.887126
# 145                              7            0.000459
# 99                              14         1178.658062
# 31                              12          250.429090
# 93                               7      1000000.000000
# 88                              10       897989.363094
# 123                              9            0.210619
# 124                              8            0.002821
# 129                              9            0.000004
# 144                              5            2.475383
# 76                              16            0.000336
# 9                               10            2.423979
# 8                               14            0.854225
# 5                               17            0.811062
# 153                              6            0.519150
# 63                               1       900254.597223
# 95                               1       954143.383141
# 64                              20       682785.236164
# 65                              20       954497.420286
# 91                               1       823640.871455
# 67                              20            0.000001
# 71                              20      1000000.000000
# 72                               6            0.036980
# 82                              20       488118.053638
# 68                              20      1000000.000000
# 70                              20            0.000001
# 81                               9            0.032353
# ..                             ...                 ...
# 42                               1       971807.933511
# 84                              20      1000000.000000
# 40                              20       678048.919095
# 100                             11          190.106326
# 110                              1       433078.467116
# 108                              1            0.000001
# 107                              1      1000000.000000
# 39                               1            0.000001
# 105                             19            0.000024
# 27                               3          473.858031
# 101                             15       567191.963262
# 30                              11            0.000187
# 34                               1            0.000001
# 35                              20            0.000001
# 36                               1            0.000001
# 37                              20            0.000001
# 94                               1            0.000001
# 38                              20            0.000002
# 92                               1       678805.164019
# 111                              1            0.000001
# 61                               1            0.000001
# 60                               1            0.000001
# 55                              14            0.000625
# 54                              14            6.591301
# 154                              1            0.000001
# 159                              1            0.000001
# 109                              1            0.000001
# 157                              1            0.000001
# 126                             17            0.023696
# 86                              20            0.000001
#
#      param_model__rf__max_features param_model__voting  \
# 90                               4                hard
# 89                               4                hard
# 127                              2                hard
# 0                                4                hard
# 145                              2                soft
# 99                               3                hard
# 31                               2                hard
# 93                               4                hard
# 88                               4                hard
# 123                              2                soft
# 124                              1                hard
# 129                              3                hard
# 144                              4                hard
# 76                               4                soft
# 9                                1                hard
# 8                                4                hard
# 5                                4                hard
# 153                              1                hard
# 63                               1                soft
# 95                               4                hard
# 64                               4                hard
# 65                               4                hard
# 91                               4                hard
# 67                               4                hard
# 71                               2                hard
# 72                               3                soft
# 82                               4                hard
# 68                               4                hard
# 70                               4                hard
# 81                               4                soft
# ..                             ...                 ...
# 42                               1                hard
# 84                               1                hard
# 40                               1                soft
# 100                              1                soft
# 110                              4                hard
# 108                              4                hard
# 107                              4                hard
# 39                               4                hard
# 105                              4                hard
# 27                               3                hard
# 101                              1                soft
# 30                               2                soft
# 34                               4                hard
# 35                               4                hard
# 36                               4                hard
# 37                               1                hard
# 94                               4                soft
# 38                               4                hard
# 92                               4                soft
# 111                              4                hard
# 61                               1                hard
# 60                               4                soft
# 55                               1                hard
# 54                               1                hard
# 154                              1                hard
# 159                              1                hard
# 109                              1                hard
# 157                              1                hard
# 126                              1                soft
# 86                               1                soft
#
#                                                 params  rank_test_score  \
# 90   {'model': VotingClassifier(estimators=[('lr', ...                1
# 89   {'model': VotingClassifier(estimators=[('lr', ...                1
# 127  {'model': VotingClassifier(estimators=[('lr', ...                1
# 0    {'model': VotingClassifier(estimators=[('lr', ...                1
# 145  {'model': VotingClassifier(estimators=[('lr', ...                1
# 99   {'model': VotingClassifier(estimators=[('lr', ...                1
# 31   {'model': VotingClassifier(estimators=[('lr', ...                1
# 93   {'model': VotingClassifier(estimators=[('lr', ...                3
# 88   {'model': VotingClassifier(estimators=[('lr', ...                3
# 123  {'model': VotingClassifier(estimators=[('lr', ...                2
# 124  {'model': VotingClassifier(estimators=[('lr', ...                2
# 129  {'model': VotingClassifier(estimators=[('lr', ...                1
# 144  {'model': VotingClassifier(estimators=[('lr', ...                1
# 76   {'model': VotingClassifier(estimators=[('lr', ...                1
# 9    {'model': VotingClassifier(estimators=[('lr', ...                1
# 8    {'model': VotingClassifier(estimators=[('lr', ...                1
# 5    {'model': VotingClassifier(estimators=[('lr', ...                1
# 153  {'model': VotingClassifier(estimators=[('lr', ...                1
# 63   {'model': VotingClassifier(estimators=[('lr', ...                1
# 95   {'model': VotingClassifier(estimators=[('lr', ...                5
# 64   {'model': VotingClassifier(estimators=[('lr', ...                1
# 65   {'model': VotingClassifier(estimators=[('lr', ...                1
# 91   {'model': VotingClassifier(estimators=[('lr', ...                5
# 67   {'model': VotingClassifier(estimators=[('lr', ...                1
# 71   {'model': VotingClassifier(estimators=[('lr', ...                1
# 72   {'model': VotingClassifier(estimators=[('lr', ...                2
# 82   {'model': VotingClassifier(estimators=[('lr', ...                1
# 68   {'model': VotingClassifier(estimators=[('lr', ...                1
# 70   {'model': VotingClassifier(estimators=[('lr', ...                1
# 81   {'model': VotingClassifier(estimators=[('lr', ...                1
# ..                                                 ...              ...
# 42   {'model': VotingClassifier(estimators=[('lr', ...                1
# 84   {'model': VotingClassifier(estimators=[('lr', ...                4
# 40   {'model': VotingClassifier(estimators=[('lr', ...                1
# 100  {'model': VotingClassifier(estimators=[('lr', ...                7
# 110  {'model': VotingClassifier(estimators=[('lr', ...                3
# 108  {'model': VotingClassifier(estimators=[('lr', ...                3
# 107  {'model': VotingClassifier(estimators=[('lr', ...                3
# 39   {'model': VotingClassifier(estimators=[('lr', ...                3
# 105  {'model': VotingClassifier(estimators=[('lr', ...                3
# 27   {'model': VotingClassifier(estimators=[('lr', ...                4
# 101  {'model': VotingClassifier(estimators=[('lr', ...                7
# 30   {'model': VotingClassifier(estimators=[('lr', ...                4
# 34   {'model': VotingClassifier(estimators=[('lr', ...                3
# 35   {'model': VotingClassifier(estimators=[('lr', ...                3
# 36   {'model': VotingClassifier(estimators=[('lr', ...                3
# 37   {'model': VotingClassifier(estimators=[('lr', ...                3
# 94   {'model': VotingClassifier(estimators=[('lr', ...                7
# 38   {'model': VotingClassifier(estimators=[('lr', ...                3
# 92   {'model': VotingClassifier(estimators=[('lr', ...                7
# 111  {'model': VotingClassifier(estimators=[('lr', ...                3
# 61   {'model': VotingClassifier(estimators=[('lr', ...                7
# 60   {'model': VotingClassifier(estimators=[('lr', ...                7
# 55   {'model': VotingClassifier(estimators=[('lr', ...                7
# 54   {'model': VotingClassifier(estimators=[('lr', ...                7
# 154  {'model': VotingClassifier(estimators=[('lr', ...                6
# 159  {'model': VotingClassifier(estimators=[('lr', ...                6
# 109  {'model': VotingClassifier(estimators=[('lr', ...                8
# 157  {'model': VotingClassifier(estimators=[('lr', ...                6
# 126  {'model': VotingClassifier(estimators=[('lr', ...                8
# 86   {'model': VotingClassifier(estimators=[('lr', ...                8
#
#      split0_test_score  split0_train_score  split1_test_score  \
# 90            0.966667            0.983333           0.966667
# 89            0.966667            0.983333           0.966667
# 127           0.966667            0.991667           1.000000
# 0             0.966667            0.991667           1.000000
# 145           0.966667            0.983333           0.966667
# 99            0.966667            0.983333           1.000000
# 31            0.966667            0.975000           1.000000
# 93            0.966667            0.975000           0.966667
# 88            0.966667            0.975000           0.966667
# 123           0.966667            0.975000           1.000000
# 124           0.966667            0.975000           1.000000
# 129           0.966667            0.975000           1.000000
# 144           0.966667            0.983333           1.000000
# 76            0.966667            0.975000           0.966667
# 9             0.966667            0.991667           1.000000
# 8             0.966667            0.983333           1.000000
# 5             0.966667            0.983333           1.000000
# 153           0.966667            0.983333           1.000000
# 63            0.966667            1.000000           0.966667
# 95            0.966667            1.000000           0.966667
# 64            0.966667            1.000000           0.966667
# 65            0.966667            1.000000           0.966667
# 91            0.966667            1.000000           0.966667
# 67            0.966667            1.000000           0.966667
# 71            0.966667            1.000000           0.966667
# 72            0.966667            0.975000           0.966667
# 82            0.966667            0.983333           0.966667
# 68            0.966667            1.000000           0.966667
# 70            0.966667            1.000000           0.966667
# 81            0.966667            0.991667           0.966667
# ..                 ...                 ...                ...
# 42            0.966667            0.983333           0.966667
# 84            0.966667            0.983333           0.966667
# 40            0.966667            0.966667           0.966667
# 100           0.966667            0.983333           0.966667
# 110           0.966667            1.000000           0.966667
# 108           0.966667            1.000000           0.966667
