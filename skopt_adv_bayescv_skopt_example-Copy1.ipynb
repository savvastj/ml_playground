# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

from sklearn.datasets import load_iris, load_digits
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

import pandas as pd

X, y = load_digits(10, True)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=0)

# used to try different model classes
pipe = Pipeline([
    ('model', SVC())
])

# single categorical value of 'model' parameter is used  to set the model class
lin_search = {
    'model': Categorical([LinearSVC()]),
    'model__C': Real(1e-6, 1e+6, prior='log-uniform'),
}

dtc_search = {
    'model': Categorical([DecisionTreeClassifier()]),
    'model__max_depth': Integer(1,32),
    'model__min_samples_split': Real(1e-3, 1.0, prior='log-uniform'),
}

svc_search = {
    'model': Categorical([SVC()]),
    'model__C': Real(1e-6, 1e+6, prior='log-uniform'),
    'model__gamma': Real(1e-6, 1e+1, prior='log-uniform'),
    'model__degree': Integer(1,8),
    'model__kernel': Categorical(['linear', 'poly', 'rbf']),
}

# %%
opt = BayesSearchCV(
    pipe,
    [(lin_search, 16), (dtc_search, 24), (svc_search, 32)], # (parameter space, # of evaluations)
    n_jobs=-1
)

opt.fit(X_train, y_train)

# %%
opt.best_estimator_
# Out:
# Pipeline(steps=[('model', SVC(C=0.0012587583006411721, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=7, gamma=9.9999999999999995e-07,
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False))])

# %%
type(opt.cv_results_)
# Out:
# collections.defaultdict

# %%
opt.cv_results_.keys()
# Out:
# dict_keys(['split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score', 'split0_train_score', 'split1_train_score', 'split2_train_score', 'mean_train_score', 'std_train_score', 'mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_model', 'param_model__C', 'params', 'param_model__max_depth', 'param_model__min_samples_split', 'param_model__degree', 'param_model__gamma', 'param_model__kernel'])

# %%
len(opt.cv_results_.keys())
# Out:
# 23

# %%
len(opt.cv_results_.items())
# Out:
# 23

# %%
cv_results = pd.DataFrame(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9c08488910b3> in <module>()
# ----> 1 cv_results = pd.DataFrame(opt.cv_results_)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5592     # figure out the index, if necessary
#    5593     if index is None:
# -> 5594         index = extract_index(arrays)
#    5595     else:
#    5596         index = _ensure_index(index)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5640             lengths = list(set(raw_lengths))
#    5641             if len(lengths) > 1:
# -> 5642                 raise ValueError('arrays must all be same length')
#    5643
#    5644             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
cv_results = pd.DataFrame.from_dict(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4bc67660de54> in <module>()
# ----> 1 cv_results = pd.DataFrame.from_dict(opt.cv_results_)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype)
#     859             raise ValueError('only recognize index or columns for orient')
#     860
# --> 861         return cls(data, index=index, columns=columns, dtype=dtype)
#     862
#     863     def to_dict(self, orient='dict'):
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5592     # figure out the index, if necessary
#    5593     if index is None:
# -> 5594         index = extract_index(arrays)
#    5595     else:
#    5596         index = _ensure_index(index)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5640             lengths = list(set(raw_lengths))
#    5641             if len(lengths) > 1:
# -> 5642                 raise ValueError('arrays must all be same length')
#    5643
#    5644             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
for k, v in opt.cv_results_.items():
    print(k, len(v))
# Out:
# split0_test_score 72
# split1_test_score 72
# split2_test_score 72
# mean_test_score 72
# std_test_score 72
# rank_test_score 72
# split0_train_score 72
# split1_train_score 72
# split2_train_score 72
# mean_train_score 72
# std_train_score 72
# mean_fit_time 72
# std_fit_time 72
# mean_score_time 72
# std_score_time 72
# param_model 72
# param_model__C 48
# params 72
# param_model__max_depth 24
# param_model__min_samples_split 24
# param_model__degree 32
# param_model__gamma 32
# param_model__kernel 32

# %%
cv_results = pd.DataFrame(opt.cv_results_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-9c08488910b3> in <module>()
# ----> 1 cv_results = pd.DataFrame(opt.cv_results_)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5592     # figure out the index, if necessary
#    5593     if index is None:
# -> 5594         index = extract_index(arrays)
#    5595     else:
#    5596         index = _ensure_index(index)
#
# /home/savvas-mint/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5640             lengths = list(set(raw_lengths))
#    5641             if len(lengths) > 1:
# -> 5642                 raise ValueError('arrays must all be same length')
#    5643
#    5644             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### Hacky solutions from [here](https://stackoverflow.com/questions/19736080/creating-dataframe-from-a-dictionary-where-entries-have-different-lengths)

# %%
cv_results = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in opt.cv_results_.items()]))

# %%
cv_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 23 columns):
# mean_fit_time                     72 non-null float64
# mean_score_time                   72 non-null float64
# mean_test_score                   72 non-null float64
# mean_train_score                  72 non-null float64
# param_model                       72 non-null object
# param_model__C                    48 non-null float64
# param_model__degree               32 non-null float64
# param_model__gamma                32 non-null float64
# param_model__kernel               32 non-null object
# param_model__max_depth            24 non-null float64
# param_model__min_samples_split    24 non-null float64
# params                            72 non-null object
# rank_test_score                   72 non-null int64
# split0_test_score                 72 non-null float64
# split0_train_score                72 non-null float64
# split1_test_score                 72 non-null float64
# split1_train_score                72 non-null float64
# split2_test_score                 72 non-null float64
# split2_train_score                72 non-null float64
# std_fit_time                      72 non-null float64
# std_score_time                    72 non-null float64
# std_test_score                    72 non-null float64
# std_train_score                   72 non-null float64
# dtypes: float64(19), int64(1), object(3)
# memory usage: 13.0+ KB

# %%
cv_results2 = pd.DataFrame.from_dict(opt.cv_results_, orient='index').transpose()

# %%
cv_results2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 23 columns):
# split0_test_score                 72 non-null object
# split1_test_score                 72 non-null object
# split2_test_score                 72 non-null object
# mean_test_score                   72 non-null object
# std_test_score                    72 non-null object
# rank_test_score                   72 non-null object
# split0_train_score                72 non-null object
# split1_train_score                72 non-null object
# split2_train_score                72 non-null object
# mean_train_score                  72 non-null object
# std_train_score                   72 non-null object
# mean_fit_time                     72 non-null object
# std_fit_time                      72 non-null object
# mean_score_time                   72 non-null object
# std_score_time                    72 non-null object
# param_model                       72 non-null object
# param_model__C                    48 non-null object
# params                            72 non-null object
# param_model__max_depth            24 non-null object
# param_model__min_samples_split    24 non-null object
# param_model__degree               32 non-null object
# param_model__gamma                32 non-null object
# param_model__kernel               32 non-null object
# dtypes: object(23)
# memory usage: 13.0+ KB

# %%
pd.options.display.max_columns = None

# %%
cv_results.sort_values('rank_test_score')
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 22       0.010681         0.000298         0.847810          0.958412
# 1        0.032809         0.021864         0.962138          0.986274
# 28       0.012170         0.000442         0.838901          0.963613
# 15       0.189243         0.009092         0.959911          0.992950
# 37       0.011029         0.000352         0.851522          0.985888
# 64       0.033273         0.018737         0.977728          0.990719
# 58       0.032862         0.021346         0.980698          0.992204
# 45       0.030359         0.015567         0.976986          1.000000
# 46       0.029971         0.015279         0.976986          1.000000
# 54       0.035202         0.019511         0.978471          1.000000
# 49       0.038111         0.022238         0.978471          1.000000
# 70       0.030742         0.015677         0.976986          1.000000
# 35       0.012290         0.000466         0.843356          1.000000
# 57       0.034258         0.017469         0.979213          0.992946
# 65       0.032319         0.016049         0.976986          1.000000
# 66       0.032243         0.017380         0.976986          1.000000
# 68       0.031685         0.016361         0.976986          1.000000
# 69       0.029640         0.015388         0.976986          1.000000
# 27       0.011525         0.000472         0.831477          0.944299
# 56       0.030674         0.015986         0.979213          0.998888
# 71       0.030762         0.015543         0.976986          1.000000
# 8        0.109684         0.027132         0.958426          0.996290
# 19       0.012004         0.000428         0.835189          0.985888
# 3        0.259975         0.011960         0.944321          0.997777
# 20       0.012320         0.000429         0.835189          0.985888
# 50       0.037802         0.020124         0.976986          1.000000
# 52       0.031083         0.016175         0.976986          1.000000
# 33       0.012652         0.000676         0.835932          0.969179
# 10       0.152789         0.038818         0.941351          0.997777
# 40       0.038881         0.014462         0.970304          1.000000
# ..            ...              ...              ...               ...
# 0        0.139360         0.038325         0.937639          0.997408
# 16       0.012282         0.000728         0.832962          0.946899
# 34       0.013014         0.000640         0.834447          1.000000
# 41       0.258716         0.074169         0.106162          1.000000
# 30       0.005599         0.000291         0.685226          0.710447
# 39       0.001766         0.000259         0.204900          0.204896
# 38       0.001855         0.000266         0.204900          0.204896
# 13       0.300692         0.013003         0.940609          0.997775
# 2        0.015883         0.020555         0.925761          0.933927
# 36       0.002002         0.000352         0.204900          0.204896
# 48       0.035873         0.028617         0.976244          0.987003
# 11       0.323979         0.019159         0.940609          0.997775
# 23       0.010618         0.000331         0.828508          0.936127
# 24       0.004059         0.000658         0.291017          0.296210
# 32       0.002963         0.000601         0.204900          0.204896
# 26       0.003981         0.000650         0.291017          0.296210
# 18       0.011154         0.000674         0.801782          0.894170
# 21       0.008958         0.000352         0.801782          0.881197
# 53       0.038051         0.013582         0.965850          1.000000
# 51       0.039301         0.013586         0.965850          1.000000
# 7        0.029183         0.006451         0.925019          0.932444
# 29       0.001983         0.000306         0.204900          0.204896
# 4        0.035355         0.012453         0.901262          0.907585
# 14       0.219409         0.003822         0.939124          0.997405
# 31       0.001762         0.000261         0.204900          0.204896
# 17       0.006399         0.000759         0.562732          0.578721
# 9        0.100646         0.024281         0.936897          0.993327
# 55       0.146525         0.039969         0.106162          0.106161
# 6        0.015673         0.000420         0.896808          0.902016
# 67       0.299197         0.070973         0.106162          1.000000
#
#                                           param_model  param_model__C  \
# 22  DecisionTreeClassifier(class_weight=None, crit...      905.688142
# 1   LinearSVC(C=0.0010880211554764913, class_weigh...        0.001088
# 28  DecisionTreeClassifier(class_weight=None, crit...        9.400559
# 15  LinearSVC(C=0.0046305439933453842, class_weigh...        0.004631
# 37  DecisionTreeClassifier(class_weight=None, crit...   144091.513974
# 64  SVC(C=0.0011295614767239265, cache_size=200, c...             NaN
# 58  SVC(C=0.0012587583006411721, cache_size=200, c...             NaN
# 45  SVC(C=73.05931532523995, cache_size=200, class...     6421.165637
# 46  SVC(C=905.68814243472389, cache_size=200, clas...   522520.878477
# 54  SVC(C=480807.09788999299, cache_size=200, clas...             NaN
# 49  SVC(C=66207.89251739216, cache_size=200, class...             NaN
# 70  SVC(C=522520.87847727927, cache_size=200, clas...             NaN
# 35  DecisionTreeClassifier(class_weight=None, crit...       59.686036
# 57  SVC(C=0.0015236853341282384, cache_size=200, c...             NaN
# 65  SVC(C=10840.498515429348, cache_size=200, clas...             NaN
# 66  SVC(C=0.24126784628980572, cache_size=200, cla...             NaN
# 68  SVC(C=33674.940754626572, cache_size=200, clas...             NaN
# 69  SVC(C=6421.1656372843954, cache_size=200, clas...             NaN
# 27  DecisionTreeClassifier(class_weight=None, crit...      950.184496
# 56  SVC(C=0.0046427585738361386, cache_size=200, c...             NaN
# 71  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
# 8   LinearSVC(C=0.020794866193685424, class_weight...        0.020795
# 19  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 3   LinearSVC(C=13.670559734761389, class_weight=N...       13.670560
# 20  DecisionTreeClassifier(class_weight=None, crit...        0.000825
# 50  SVC(C=177132.14711581811, cache_size=200, clas...             NaN
# 52  SVC(C=9.4005589344324161, cache_size=200, clas...             NaN
# 33  DecisionTreeClassifier(class_weight=None, crit...        0.001524
# 10  LinearSVC(C=1000000.0, class_weight=None, dual...  1000000.000000
# 40  SVC(C=0.16305447853731186, cache_size=200, cla...        0.001130
# ..                                                ...             ...
# 0   LinearSVC(C=25.917982562967296, class_weight=N...       25.917983
# 16  DecisionTreeClassifier(class_weight=None, crit...        0.163054
# 34  DecisionTreeClassifier(class_weight=None, crit...        0.001259
# 41  SVC(C=3.0095695254490749, cache_size=200, clas...    10840.498515
# 30  DecisionTreeClassifier(class_weight=None, crit...   480807.097890
# 39  DecisionTreeClassifier(class_weight=None, crit...        0.560682
# 38  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 13  LinearSVC(C=151021.91198428048, class_weight=N...   151021.911984
# 2   LinearSVC(C=1.652338704483245e-05, class_weigh...        0.000017
# 36  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 48  SVC(C=0.00065438972804037214, cache_size=200, ...             NaN
# 11  LinearSVC(C=17600.348252547759, class_weight=N...    17600.348253
# 23  DecisionTreeClassifier(class_weight=None, crit...        0.000114
# 24  DecisionTreeClassifier(class_weight=None, crit...        0.000654
# 32  DecisionTreeClassifier(class_weight=None, crit...        0.004643
# 26  DecisionTreeClassifier(class_weight=None, crit...   177132.147116
# 18  DecisionTreeClassifier(class_weight=None, crit...        0.000149
# 21  DecisionTreeClassifier(class_weight=None, crit...       73.059315
# 53  SVC(C=0.97208480501522831, cache_size=200, cla...             NaN
# 51  SVC(C=950.18449570056146, cache_size=200, clas...             NaN
# 7   LinearSVC(C=1.4826216325636683e-05, class_weig...        0.000015
# 29  DecisionTreeClassifier(class_weight=None, crit...        0.972085
# 4   LinearSVC(C=5.0826189602651539e-06, class_weig...        0.000005
# 14  LinearSVC(C=6657.0531126175047, class_weight=N...     6657.053113
# 31  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 17  DecisionTreeClassifier(class_weight=None, crit...        3.009570
# 9   LinearSVC(C=1394.2592600662285, class_weight=N...     1394.259260
# 55  SVC(C=9.9999999999999995e-07, cache_size=200, ...             NaN
# 6   LinearSVC(C=1.4826216325636683e-05, class_weig...        0.000004
# 67  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
#
#     param_model__degree  param_model__gamma param_model__kernel  \
# 22                  1.0            0.000001                poly
# 1                   2.0            0.227838                 rbf
# 28                  1.0            0.000001                poly
# 15                  1.0            0.000001              linear
# 37                  NaN                 NaN                 NaN
# 64                  NaN                 NaN                 NaN
# 58                  NaN                 NaN                 NaN
# 45                  NaN                 NaN                 NaN
# 46                  NaN                 NaN                 NaN
# 54                  NaN                 NaN                 NaN
# 49                  NaN                 NaN                 NaN
# 70                  NaN                 NaN                 NaN
# 35                  NaN                 NaN                 NaN
# 57                  NaN                 NaN                 NaN
# 65                  NaN                 NaN                 NaN
# 66                  NaN                 NaN                 NaN
# 68                  NaN                 NaN                 NaN
# 69                  NaN                 NaN                 NaN
# 27                  1.0           10.000000                 rbf
# 56                  NaN                 NaN                 NaN
# 71                  NaN                 NaN                 NaN
# 8                   6.0            0.419586              linear
# 19                  2.0            0.000001              linear
# 3                   5.0            0.000024                poly
# 20                  8.0            0.000001              linear
# 50                  NaN                 NaN                 NaN
# 52                  NaN                 NaN                 NaN
# 33                  NaN                 NaN                 NaN
# 10                  2.0            0.000008                 rbf
# 40                  NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 0                   7.0            2.249762                poly
# 16                  1.0            0.000001              linear
# 34                  NaN                 NaN                 NaN
# 41                  NaN                 NaN                 NaN
# 30                  1.0           10.000000              linear
# 39                  NaN                 NaN                 NaN
# 38                  NaN                 NaN                 NaN
# 13                  8.0            6.982428                poly
# 2                   8.0            0.000002                 rbf
# 36                  NaN                 NaN                 NaN
# 48                  NaN                 NaN                 NaN
# 11                  8.0           10.000000                poly
# 23                  8.0           10.000000              linear
# 24                  1.0            0.000001              linear
# 32                  NaN                 NaN                 NaN
# 26                  1.0            0.000001              linear
# 18                  7.0            0.000001              linear
# 21                  1.0            0.000001              linear
# 53                  NaN                 NaN                 NaN
# 51                  NaN                 NaN                 NaN
# 7                   3.0            0.000012                 rbf
# 29                  1.0            0.000001              linear
# 4                   6.0            0.159019                 rbf
# 14                  1.0            0.000019                 rbf
# 31                  1.0           10.000000              linear
# 17                  5.0            1.181121              linear
# 9                   2.0            0.000017                 rbf
# 55                  NaN                 NaN                 NaN
# 6                   4.0            0.000371              linear
# 67                  NaN                 NaN                 NaN
#
#     param_model__max_depth  param_model__min_samples_split  \
# 22                     1.0                        0.053418
# 1                      7.0                        0.212374
# 28                     NaN                             NaN
# 15                     1.0                        0.872294
# 37                     NaN                             NaN
# 64                     NaN                             NaN
# 58                     NaN                             NaN
# 45                     NaN                             NaN
# 46                     NaN                             NaN
# 54                     NaN                             NaN
# 49                     NaN                             NaN
# 70                     NaN                             NaN
# 35                     NaN                             NaN
# 57                     NaN                             NaN
# 65                     NaN                             NaN
# 66                     NaN                             NaN
# 68                     NaN                             NaN
# 69                     NaN                             NaN
# 27                     NaN                             NaN
# 56                     NaN                             NaN
# 71                     NaN                             NaN
# 8                     30.0                        0.596927
# 19                    32.0                        0.001470
# 3                     12.0                        0.002432
# 20                     1.0                        0.005991
# 50                     NaN                             NaN
# 52                     NaN                             NaN
# 33                     NaN                             NaN
# 10                    32.0                        0.741656
# 40                     NaN                             NaN
# ..                     ...                             ...
# 0                     12.0                        0.009008
# 16                     1.0                        0.004473
# 34                     NaN                             NaN
# 41                     NaN                             NaN
# 30                     NaN                             NaN
# 39                     NaN                             NaN
# 38                     NaN                             NaN
# 13                     1.0                        1.000000
# 2                     20.0                        0.031262
# 36                     NaN                             NaN
# 48                     NaN                             NaN
# 11                    32.0                        0.010221
# 23                     1.0                        0.027750
# 24                     NaN                             NaN
# 32                     NaN                             NaN
# 26                     NaN                             NaN
# 18                    32.0                        0.001000
# 21                    32.0                        0.003117
# 53                     NaN                             NaN
# 51                     NaN                             NaN
# 7                     23.0                        0.011510
# 29                     NaN                             NaN
# 4                     18.0                        0.002574
# 14                    31.0                        0.124290
# 31                     NaN                             NaN
# 17                    14.0                        0.004824
# 9                     29.0                        0.009001
# 55                     NaN                             NaN
# 6                     18.0                        0.007445
# 67                     NaN                             NaN
#
#                                                params  rank_test_score  \
# 22  {'model': DecisionTreeClassifier(class_weight=...                1
# 1   {'model': LinearSVC(C=0.0010880211554764913, c...                1
# 28  {'model': DecisionTreeClassifier(class_weight=...                1
# 15  {'model': LinearSVC(C=0.0046305439933453842, c...                1
# 37  {'model': DecisionTreeClassifier(class_weight=...                1
# 64  {'model': SVC(C=0.0011295614767239265, cache_s...                1
# 58  {'model': SVC(C=0.0012587583006411721, cache_s...                1
# 45  {'model': SVC(C=73.05931532523995, cache_size=...                1
# 46  {'model': SVC(C=905.68814243472389, cache_size...                1
# 54  {'model': SVC(C=480807.09788999299, cache_size...                1
# 49  {'model': SVC(C=66207.89251739216, cache_size=...                1
# 70  {'model': SVC(C=522520.87847727927, cache_size...                2
# 35  {'model': DecisionTreeClassifier(class_weight=...                2
# 57  {'model': SVC(C=0.0015236853341282384, cache_s...                2
# 65  {'model': SVC(C=10840.498515429348, cache_size...                2
# 66  {'model': SVC(C=0.24126784628980572, cache_siz...                2
# 68  {'model': SVC(C=33674.940754626572, cache_size...                2
# 69  {'model': SVC(C=6421.1656372843954, cache_size...                2
# 27  {'model': DecisionTreeClassifier(class_weight=...                2
# 56  {'model': SVC(C=0.0046427585738361386, cache_s...                2
# 71  {'model': SVC(C=1000000.0, cache_size=200, cla...                2
# 8   {'model': LinearSVC(C=0.020794866193685424, cl...                2
# 19  {'model': DecisionTreeClassifier(class_weight=...                2
# 3   {'model': LinearSVC(C=13.670559734761389, clas...                2
# 20  {'model': DecisionTreeClassifier(class_weight=...                2
# 50  {'model': SVC(C=177132.14711581811, cache_size...                3
# 52  {'model': SVC(C=9.4005589344324161, cache_size...                3
# 33  {'model': DecisionTreeClassifier(class_weight=...                3
# 10  {'model': LinearSVC(C=1000000.0, class_weight=...                3
# 40  {'model': SVC(C=0.16305447853731186, cache_siz...                3
# ..                                                ...              ...
# 0   {'model': LinearSVC(C=25.917982562967296, clas...                4
# 16  {'model': DecisionTreeClassifier(class_weight=...                4
# 34  {'model': DecisionTreeClassifier(class_weight=...                4
# 41  {'model': SVC(C=3.0095695254490749, cache_size...                4
# 30  {'model': DecisionTreeClassifier(class_weight=...                4
# 39  {'model': DecisionTreeClassifier(class_weight=...                5
# 38  {'model': DecisionTreeClassifier(class_weight=...                5
# 13  {'model': LinearSVC(C=151021.91198428048, clas...                5
# 2   {'model': LinearSVC(C=1.652338704483245e-05, c...                5
# 36  {'model': DecisionTreeClassifier(class_weight=...                5
# 48  {'model': SVC(C=0.00065438972804037214, cache_...                5
# 11  {'model': LinearSVC(C=17600.348252547759, clas...                5
# 23  {'model': DecisionTreeClassifier(class_weight=...                5
# 24  {'model': DecisionTreeClassifier(class_weight=...                5
# 32  {'model': DecisionTreeClassifier(class_weight=...                5
# 26  {'model': DecisionTreeClassifier(class_weight=...                5
# 18  {'model': DecisionTreeClassifier(class_weight=...                6
# 21  {'model': DecisionTreeClassifier(class_weight=...                6
# 53  {'model': SVC(C=0.97208480501522831, cache_siz...                6
# 51  {'model': SVC(C=950.18449570056146, cache_size...                6
# 7   {'model': LinearSVC(C=1.4826216325636683e-05, ...                6
# 29  {'model': DecisionTreeClassifier(class_weight=...                7
# 4   {'model': LinearSVC(C=5.0826189602651539e-06, ...                7
# 14  {'model': LinearSVC(C=6657.0531126175047, clas...                7
# 31  {'model': DecisionTreeClassifier(class_weight=...                7
# 69       0.029640         0.015388         0.976986          1.000000
# 68       0.031685         0.016361         0.976986          1.000000
# 48       0.035873         0.028617         0.976244          0.987003
# 40       0.038881         0.014462         0.970304          1.000000
# 53       0.038051         0.013582         0.965850          1.000000
# 51       0.039301         0.013586         0.965850          1.000000
# 1        0.032809         0.021864         0.962138          0.986274
# 15       0.189243         0.009092         0.959911          0.992950
# 8        0.109684         0.027132         0.958426          0.996290
# 3        0.259975         0.011960         0.944321          0.997777
# 10       0.152789         0.038818         0.941351          0.997777
# ..            ...              ...              ...               ...
# 22       0.010681         0.000298         0.847810          0.958412
# 35       0.012290         0.000466         0.843356          1.000000
# 28       0.012170         0.000442         0.838901          0.963613
# 33       0.012652         0.000676         0.835932          0.969179
# 19       0.012004         0.000428         0.835189          0.985888
# 20       0.012320         0.000429         0.835189          0.985888
# 34       0.013014         0.000640         0.834447          1.000000
# 16       0.012282         0.000728         0.832962          0.946899
# 27       0.011525         0.000472         0.831477          0.944299
# 25       0.012523         0.000755         0.829993          0.946899
# 23       0.010618         0.000331         0.828508          0.936127
# 18       0.011154         0.000674         0.801782          0.894170
# 21       0.008958         0.000352         0.801782          0.881197
# 30       0.005599         0.000291         0.685226          0.710447
# 17       0.006399         0.000759         0.562732          0.578721
# 26       0.003981         0.000650         0.291017          0.296210
# 24       0.004059         0.000658         0.291017          0.296210
# 38       0.001855         0.000266         0.204900          0.204896
# 39       0.001766         0.000259         0.204900          0.204896
# 29       0.001983         0.000306         0.204900          0.204896
# 32       0.002963         0.000601         0.204900          0.204896
# 31       0.001762         0.000261         0.204900          0.204896
# 36       0.002002         0.000352         0.204900          0.204896
# 47       0.175900         0.050247         0.106162          0.106161
# 44       0.185017         0.053445         0.106162          0.106161
# 43       0.160836         0.043389         0.106162          0.106161
# 42       0.191699         0.053589         0.106162          0.106161
# 67       0.299197         0.070973         0.106162          1.000000
# 41       0.258716         0.074169         0.106162          1.000000
# 55       0.146525         0.039969         0.106162          0.106161
#
#                                           param_model  param_model__C  \
# 58  SVC(C=0.0012587583006411721, cache_size=200, c...             NaN
# 56  SVC(C=0.0046427585738361386, cache_size=200, c...             NaN
# 57  SVC(C=0.0015236853341282384, cache_size=200, c...             NaN
# 49  SVC(C=66207.89251739216, cache_size=200, class...             NaN
# 54  SVC(C=480807.09788999299, cache_size=200, clas...             NaN
# 64  SVC(C=0.0011295614767239265, cache_size=200, c...             NaN
# 71  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
# 45  SVC(C=73.05931532523995, cache_size=200, class...     6421.165637
# 46  SVC(C=905.68814243472389, cache_size=200, clas...   522520.878477
# 50  SVC(C=177132.14711581811, cache_size=200, clas...             NaN
# 52  SVC(C=9.4005589344324161, cache_size=200, clas...             NaN
# 59  SVC(C=59.686035785521085, cache_size=200, clas...             NaN
# 60  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
# 61  SVC(C=144091.51397375209, cache_size=200, clas...             NaN
# 62  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
# 63  SVC(C=0.56068160627911412, cache_size=200, cla...             NaN
# 66  SVC(C=0.24126784628980572, cache_size=200, cla...             NaN
# 65  SVC(C=10840.498515429348, cache_size=200, clas...             NaN
# 70  SVC(C=522520.87847727927, cache_size=200, clas...             NaN
# 69  SVC(C=6421.1656372843954, cache_size=200, clas...             NaN
# 68  SVC(C=33674.940754626572, cache_size=200, clas...             NaN
# 48  SVC(C=0.00065438972804037214, cache_size=200, ...             NaN
# 40  SVC(C=0.16305447853731186, cache_size=200, cla...        0.001130
# 53  SVC(C=0.97208480501522831, cache_size=200, cla...             NaN
# 51  SVC(C=950.18449570056146, cache_size=200, clas...             NaN
# 1   LinearSVC(C=0.0010880211554764913, class_weigh...        0.001088
# 15  LinearSVC(C=0.0046305439933453842, class_weigh...        0.004631
# 8   LinearSVC(C=0.020794866193685424, class_weight...        0.020795
# 3   LinearSVC(C=13.670559734761389, class_weight=N...       13.670560
# 10  LinearSVC(C=1000000.0, class_weight=None, dual...  1000000.000000
# ..                                                ...             ...
# 22  DecisionTreeClassifier(class_weight=None, crit...      905.688142
# 35  DecisionTreeClassifier(class_weight=None, crit...       59.686036
# 28  DecisionTreeClassifier(class_weight=None, crit...        9.400559
# 33  DecisionTreeClassifier(class_weight=None, crit...        0.001524
# 19  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 20  DecisionTreeClassifier(class_weight=None, crit...        0.000825
# 34  DecisionTreeClassifier(class_weight=None, crit...        0.001259
# 16  DecisionTreeClassifier(class_weight=None, crit...        0.163054
# 27  DecisionTreeClassifier(class_weight=None, crit...      950.184496
# 25  DecisionTreeClassifier(class_weight=None, crit...    66207.892517
# 23  DecisionTreeClassifier(class_weight=None, crit...        0.000114
# 18  DecisionTreeClassifier(class_weight=None, crit...        0.000149
# 21  DecisionTreeClassifier(class_weight=None, crit...       73.059315
# 30  DecisionTreeClassifier(class_weight=None, crit...   480807.097890
# 17  DecisionTreeClassifier(class_weight=None, crit...        3.009570
# 26  DecisionTreeClassifier(class_weight=None, crit...   177132.147116
# 24  DecisionTreeClassifier(class_weight=None, crit...        0.000654
# 38  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 39  DecisionTreeClassifier(class_weight=None, crit...        0.560682
# 29  DecisionTreeClassifier(class_weight=None, crit...        0.972085
# 32  DecisionTreeClassifier(class_weight=None, crit...        0.004643
# 31  DecisionTreeClassifier(class_weight=None, crit...        0.000001
# 36  DecisionTreeClassifier(class_weight=None, crit...  1000000.000000
# 47  SVC(C=0.00011367029759625476, cache_size=200, ...  1000000.000000
# 44  SVC(C=0.00082456923185640781, cache_size=200, ...    33674.940755
# 43  SVC(C=1.3822176635811299e-06, cache_size=200, ...  1000000.000000
# 42  SVC(C=0.00014857675443101363, cache_size=200, ...        0.241268
# 67  SVC(C=1000000.0, cache_size=200, class_weight=...             NaN
# 41  SVC(C=3.0095695254490749, cache_size=200, clas...    10840.498515
# 55  SVC(C=9.9999999999999995e-07, cache_size=200, ...             NaN
#
#     param_model__degree  param_model__gamma param_model__kernel  \
# 58                  NaN                 NaN                 NaN
# 56                  NaN                 NaN                 NaN
# 57                  NaN                 NaN                 NaN
# 49                  NaN                 NaN                 NaN
# 19                    32.0                        0.001470
# 20                     1.0                        0.005991
# 34                     NaN                             NaN
# 16                     1.0                        0.004473
# 27                     NaN                             NaN
# 25                     NaN                             NaN
# 23                     1.0                        0.027750
# 18                    32.0                        0.001000
# 21                    32.0                        0.003117
# 30                     NaN                             NaN
# 17                    14.0                        0.004824
# 26                     NaN                             NaN
# 24                     NaN                             NaN
# 38                     NaN                             NaN
# 39                     NaN                             NaN
# 29                     NaN                             NaN
# 32                     NaN                             NaN
# 31                     NaN                             NaN
# 36                     NaN                             NaN
# 47                     NaN                             NaN
# 44                     NaN                             NaN
# 43                     NaN                             NaN
# 42                     NaN                             NaN
# 67                     NaN                             NaN
# 41                     NaN                             NaN
# 55                     NaN                             NaN
#
#                                                params  rank_test_score  \
# 58  {'model': SVC(C=0.0012587583006411721, cache_s...                1
# 56  {'model': SVC(C=0.0046427585738361386, cache_s...                2
# 57  {'model': SVC(C=0.0015236853341282384, cache_s...                2
# 49  {'model': SVC(C=66207.89251739216, cache_size=...                1
# 54  {'model': SVC(C=480807.09788999299, cache_size...                1
# 64  {'model': SVC(C=0.0011295614767239265, cache_s...                1
# 71  {'model': SVC(C=1000000.0, cache_size=200, cla...                2
# 45  {'model': SVC(C=73.05931532523995, cache_size=...                1
# 46  {'model': SVC(C=905.68814243472389, cache_size...                1
# 50  {'model': SVC(C=177132.14711581811, cache_size...                3
# 52  {'model': SVC(C=9.4005589344324161, cache_size...                3
# 59  {'model': SVC(C=59.686035785521085, cache_size...                4
# 60  {'model': SVC(C=1000000.0, cache_size=200, cla...                4
# 61  {'model': SVC(C=144091.51397375209, cache_size...                4
# 62  {'model': SVC(C=1000000.0, cache_size=200, cla...                4
# 63  {'model': SVC(C=0.56068160627911412, cache_siz...                4
# 66  {'model': SVC(C=0.24126784628980572, cache_siz...                2
# 65  {'model': SVC(C=10840.498515429348, cache_size...                2
# 70  {'model': SVC(C=522520.87847727927, cache_size...                2
# 69  {'model': SVC(C=6421.1656372843954, cache_size...                2
# 68  {'model': SVC(C=33674.940754626572, cache_size...                2
# 48  {'model': SVC(C=0.00065438972804037214, cache_...                5
# 40  {'model': SVC(C=0.16305447853731186, cache_siz...                3
# 53  {'model': SVC(C=0.97208480501522831, cache_siz...                6
# 51  {'model': SVC(C=950.18449570056146, cache_size...                6
# 1   {'model': LinearSVC(C=0.0010880211554764913, c...                1
# 15  {'model': LinearSVC(C=0.0046305439933453842, c...                1
# 8   {'model': LinearSVC(C=0.020794866193685424, cl...                2
# 3   {'model': LinearSVC(C=13.670559734761389, clas...                2
# 10  {'model': LinearSVC(C=1000000.0, class_weight=...                3
# ..                                                ...              ...
# 22  {'model': DecisionTreeClassifier(class_weight=...                1
# 35  {'model': DecisionTreeClassifier(class_weight=...                2
# 28  {'model': DecisionTreeClassifier(class_weight=...                1
# 33  {'model': DecisionTreeClassifier(class_weight=...                3
# 19  {'model': DecisionTreeClassifier(class_weight=...                2
# 20  {'model': DecisionTreeClassifier(class_weight=...                2
# 34  {'model': DecisionTreeClassifier(class_weight=...                4
# 16  {'model': DecisionTreeClassifier(class_weight=...                4
# 27  {'model': DecisionTreeClassifier(class_weight=...                2
# 25  {'model': DecisionTreeClassifier(class_weight=...                3
# 23  {'model': DecisionTreeClassifier(class_weight=...                5
# 18  {'model': DecisionTreeClassifier(class_weight=...                6
# 21  {'model': DecisionTreeClassifier(class_weight=...                6
# 30  {'model': DecisionTreeClassifier(class_weight=...                4
# 17  {'model': DecisionTreeClassifier(class_weight=...                8
# 26  {'model': DecisionTreeClassifier(class_weight=...                5
# 24  {'model': DecisionTreeClassifier(class_weight=...                5
# 38  {'model': DecisionTreeClassifier(class_weight=...                5
# 39  {'model': DecisionTreeClassifier(class_weight=...                5
# 29  {'model': DecisionTreeClassifier(class_weight=...                7
# 32  {'model': DecisionTreeClassifier(class_weight=...                5
# 31  {'model': DecisionTreeClassifier(class_weight=...                7
# 36  {'model': DecisionTreeClassifier(class_weight=...                5
# 47  {'model': SVC(C=0.00011367029759625476, cache_...                4
# 44  {'model': SVC(C=0.00082456923185640781, cache_...                4
# 43  {'model': SVC(C=1.3822176635811299e-06, cache_...                4
# 42  {'model': SVC(C=0.00014857675443101363, cache_...                4
# 67  {'model': SVC(C=1000000.0, cache_size=200, cla...                8
# 41  {'model': SVC(C=3.0095695254490749, cache_size...                4
# 55  {'model': SVC(C=9.9999999999999995e-07, cache_...                8
#
#     split0_test_score  split0_train_score  split1_test_score  \
# 58           0.980088            0.991061           0.975501
# 56           0.977876            0.998883           0.975501
# 57           0.977876            0.992179           0.973274
# 49           0.973451            1.000000           0.975501
# 54           0.973451            1.000000           0.975501
# 64           0.975664            0.988827           0.975501
# 71           0.971239            1.000000           0.975501
# 45           0.971239            1.000000           0.975501
# 46           0.971239            1.000000           0.975501
# 50           0.966814            1.000000           0.977728
# 52           0.971239            1.000000           0.975501
# 59           0.971239            1.000000           0.975501
# 60           0.971239            1.000000           0.975501
# 61           0.971239            1.000000           0.975501
# 62           0.971239            1.000000           0.975501
# 63           0.971239            1.000000           0.975501
# 66           0.971239            1.000000           0.975501
# 65           0.971239            1.000000           0.975501
# 70           0.971239            1.000000           0.975501
# 69           0.971239            1.000000           0.975501
# 68           0.971239            1.000000           0.975501
# 48           0.973451            0.983240           0.977728
# 40           0.971239            1.000000           0.975501
# 53           0.964602            1.000000           0.973274
# 51           0.964602            1.000000           0.973274
# 1            0.951327            0.991061           0.964365
# 15           0.953540            0.993296           0.959911
# 8            0.957965            0.996648           0.957684
# 3            0.946903            0.998883           0.944321
# 10           0.944690            0.998883           0.942094
# ..                ...                 ...                ...
# 22           0.858407            0.949721           0.855234
# 35           0.853982            1.000000           0.861915
# 28           0.842920            0.956425           0.837416
# 33           0.838496            0.962011           0.837416
# 19           0.836283            0.983240           0.848552
# 20           0.836283            0.983240           0.848552
# 34           0.842920            1.000000           0.846325
# 16           0.849558            0.937430           0.819599
# 27           0.840708            0.934078           0.826281
# 25           0.853982            0.937430           0.817372
# 23           0.838496            0.922905           0.826281
# 18           0.814159            0.873743           0.779510
# 21           0.805310            0.871508           0.806236
# 30           0.694690            0.706145           0.677060
# 17           0.584071            0.595531           0.552339
# 26           0.294248            0.299441           0.289532
